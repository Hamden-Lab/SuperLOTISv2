# %%
from superlotis.drivers.cyberpower import *

# %%
import pylablib as pll

from superlotis.drivers.pfeiffer.pfeiffer_parameters import PUMP_PARAMETERS

import paramiko
import socket
import sys
from sshtunnel import SSHTunnelForwarder

# %%
from superlotis.tools.constants import SOPHIA_IP_ADDRESS, SOPHIA_PORT

HOST = SOPHIA_IP_ADDRESS
PORT = SOPHIA_PORT


data = "get exptime" # " ".join(sys.argv[1:])

# SOCK_DGRAM is the socket type to use for UDP sockets
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

# As you can see, there is no connect() call; UDP has no connections.
# Instead, data is directly sent to the recipient via sendto().
sock.sendto(bytes(data + "\n", "utf-8"), (HOST, PORT))
received = str(sock.recv(1024), "utf-8")

print("Sent:    ", data)
print("Received:", received)
# Out:
# Sent:     get exptime
# Received: 99

# %%
name = "pumping_power"

if name in PUMP_PARAMETERS["MVP"]:
    print("MVP parameters:", PUMP_PARAMETERS["MVP"][name])
else:
    print("No parameters found for MVP")
# Out:
# MVP parameters: Parameter(node_id='_010_PumpgStatn', dtype=<class 'bool'>, readable=True, writable=True, default=False)

# %%
print(PUMP_PARAMETERS.get(2, {}).get("heating"))
# Out:
# None

# %%
import paramiko
ssh_client =paramiko.SSHClient()
ssh_client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh_client.connect(hostname='slotis.kpno.noirlab.edu', username='slotis', password='AzTEC!SNe')

stdin,stdout,stderr=ssh_client.exec_command('ls')
print(stdout.readlines())
print(stderr.readlines())

ssh_client.close()
# Out:
# ['1\n', '150428\n', 'a\n', 'aa\n', 'adria\n', 'angles.py\n', 'angles.pyc\n', 'asciidata-1.1.1\n', 'astro1\n', 'astrolib\n', 'astrometry\n', 'astrometry.tgz\n', 'autogit\n', 'data\n', 'datadir\n', 'db\n', 'Desktop\n', 'Documents\n', 'Downloads\n', 'ethan_codebase\n', 'examples.desktop\n', 'focus_limits\n', 'galil_powercycle\n', 'harrison\n', 'junk\n', 'kelian\n', 'libxp6_1.0.2-2_amd64.deb\n', 'login.cl\n', 'login.cl.back161014\n', 'login.cl.OLD\n', 'mount_disks\n', 'Music\n', 'nutrans_icon.ico\n', 'nutrans_icon.png\n', 'old_slotis_after_reboot\n', 'perl\n', 'perl5\n', 'pete_auto\n', 'pete_auto_backup150429.tar\n', 'pete_auto_backup_150602.tar\n', 'pete_auto_backup180920.tar\n', 'Pictures\n', 'ps\n', 'Public\n', 'public_html\n', 'pysex-0.1.0\n', '\x1bq\n', 'reboot_pibox\n', 'rrd\n', 'sbf\n', 'scott\n', 'sicam_20180401.xml\n', 'sicam_20180402.xml\n', 'sicam_20180403.xml\n', 'sicam_20180404.xml\n', 'sicam_20180405.xml\n', 'sicam_20180406.xml\n', 'sicam_20180407.xml\n', 'sicam_20180408.xml\n', 'sicam_20180409.xml\n', 'si_camera\n', 'slotis_after_reboot\n', 'slotis_safe\n', 'sn17jl.coords\n', 'snap\n', 'SOPHIA-XO-System-Manual-Issue-3-4411-0158.pdf\n', 'temp\n', 'Templates\n', 'test2.bash\n', 'test.bash\n', 'test_socket\n', 'test_status.pl\n', 'uparm\n', 'vacuum.dat\n', 'vacuum.dat.2\n', 'Videos\n', 'weatherdat\n', 'wired_connection_1.info\n']
# []

# %%
HOST = "localhost" # "140.252.86.96"
PORT = 5135

with socket.create_connection((HOST, PORT), timeout=10) as s:
    #s.sendall(b"set sophia_temperature 25\n")
    s.sendall(b"get all\n")

    data = s.recv(4096)
    data = data.decode(errors="ignore")

print(data) #.decode(errors="ignore")
# Out:
# bok_UDhum 22.5
# bok_gustdir 236.26
# bok_gusts 16.57
# bok_hum 16.49
# bok_temp 83.63
# bok_timestamp 2026-06-10T21:33:43.
# bok_wdir 252.39
# bok_ws 14.88
# boltwood_ambtemp 34.4
# boltwood_cloudCond 1
# boltwood_dayADC 827
# boltwood_dayCond 2
# boltwood_rainSensor 78
# boltwood_relativeHumidityPercentage 12
# boltwood_roofCloseRequested 0
# boltwood_skyMinusAmbientTemperature -32.4
# boltwood_timestamp "2026-06-10T21:32:26Z"
# boltwood_windSpeed 7.8
# cont_rainbit_status 0
# galil_camera_status 0
# galil_count 1037133
# galil_mount_status 0
# galil_rainbit_status 0
# galil_restart Fri Jun  5 10:59:33 2026
# galil_rooflimit_status set galil_restart Fri Jun  5 10:59:33 2026
# galil_roofopen_status 1
# galil_roofshut_status 0
# galil_status OK
# hmb_junk 1000000
# metone_rh 18.1
# metone_status OK
# metone_temperature_C 31.6
# metone_temperature_F 88.8
# metone_timestamp 1781127155
# metone_update Wed Jun 10 14:32:35 2026
# metone_wind_direction 47.7
# metone_wind_speed 2.8
# pam_junk = 44.444
# sophia_temperature 25
# tcs_airmass 1.00
# tcs_az -20.5
# tcs_comm_channel 2
# tcs_count 745522
# tcs_dec +315025.1
# tcs_display_equinox 2000.000
# tcs_el 90.0
# tcs_focus 285700
# tcs_ha +00:00:01
# tcs_jd 2461202.4
# tcs_limit H
# tcs_lst 07:24:45
# tcs_motion_status 0
# tcs_ra 072305.87
# tcs_restart Fri Jun  5 10:59:33 2026
# tcs_secz 1.00
# tcs_status OK
# tcs_timestamp 1781127250
# tcs_update Wed Jun 10 14:34:10 2026
# tcs_ut 21:34:13.0
# temptrax_count 86225
# temptrax_interval 5
# temptrax_probe1 31.2
# temptrax_probe2 -73.3
# temptrax_probe3 -73.3
# temptrax_probe4 -73.3
# temptrax_restarted Fri Jun  5 10:59:33 2026
# temptrax_status OK
# temptrax_update Wed Jun 10 14:34:06 2026
# weather_count 0
# weather_stat_count 6481
# weather_stat_restart Fri Jun  5 10:59:33 2026
# weather_status OK
# .EOF

# %%
try:
    sock = socket.create_connection((HOST, PORT), timeout=5)
    print("Connected!")
    sock.close()

except Exception as e:
    print("Failed:", e)
# Out:
# Connected!

# %%
with SSHTunnelForwarder(
    #('telescope-server', 22),
    ssh_username='slotis',
    ssh_password='AzTEC!SNe',
    remote_bind_address=('localhost', 5135),
    local_bind_address=('0.0.0.0', 5135)
) as tunnel:

    s = socket.create_connection(('0.0.0.0', 5135))

    s.sendall(b'get all\n')

    data = s.recv(4096)

    print(data.decode())

    s.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 with SSHTunnelForwarder(
#       2     #('telescope-server', 22),
#       3     ssh_username='slotis',
#       4     ssh_password='AzTEC!SNe',
#       5     remote_bind_address=('localhost', 5135),
#       6     local_bind_address=('0.0.0.0', 5135)
#       7 ) as tunnel:
#       9     s = socket.create_connection(('0.0.0.0', 5135))
#      11     s.sendall(b'get all\n')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sshtunnel.py:966, in SSHTunnelForwarder.__init__(self, ssh_address_or_host, ssh_config_file, ssh_host_key, ssh_password, ssh_pkey, ssh_private_key_password, ssh_proxy, ssh_proxy_enabled, ssh_username, local_bind_address, local_bind_addresses, logger, mute_exceptions, remote_bind_address, remote_bind_addresses, set_keepalive, threaded, compression, allow_agent, host_pkey_directories, *args, **kwargs)
#     947 self._local_binds = self._consolidate_binds(self._local_binds,
#     948                                             self._remote_binds)
#     950 (self.ssh_host,
#     951  self.ssh_username,
#     952  ssh_pkey,  # still needs to go through _consolidate_auth
#    (...)
#     963      self.logger
#     964 )
# --> 966 (self.ssh_password, self.ssh_pkeys) = self._consolidate_auth(
#     967     ssh_password=ssh_password,
#     968     ssh_pkey=ssh_pkey,
#     969     ssh_pkey_password=ssh_private_key_password,
#     970     allow_agent=allow_agent,
#     971     host_pkey_directories=host_pkey_directories,
#     972     logger=self.logger
#     973 )
#     975 check_host(self.ssh_host)
#     976 check_port(self.ssh_port)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sshtunnel.py:1148, in SSHTunnelForwarder._consolidate_auth(ssh_password, ssh_pkey, ssh_pkey_password, allow_agent, host_pkey_directories, logger)
#    1133 @staticmethod
#    1134 def _consolidate_auth(ssh_password=None,
#    1135                       ssh_pkey=None,
#    (...)
#    1138                       host_pkey_directories=None,
#    1139                       logger=None):
#    1140     """
#    1141     Get sure authentication information is in place.
#    1142     ``ssh_pkey`` may be of classes:
#    (...)
#    1146
#    1147     """
# -> 1148     ssh_loaded_pkeys = SSHTunnelForwarder.get_keys(
#    1149         logger=logger,
#    1150         host_pkey_directories=host_pkey_directories,
#    1151         allow_agent=allow_agent
#    1152     )
#    1154     if isinstance(ssh_pkey, string_types):
#    1155         ssh_pkey_expanded = os.path.expanduser(ssh_pkey)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sshtunnel.py:1093, in SSHTunnelForwarder.get_keys(logger, host_pkey_directories, allow_agent)
#    1089 if host_pkey_directories is None:
#    1090     host_pkey_directories = [DEFAULT_SSH_DIRECTORY]
#    1092 paramiko_key_types = {'rsa': paramiko.RSAKey,
# -> 1093                       'dsa': paramiko.DSSKey,
#    1094                       'ecdsa': paramiko.ECDSAKey}
#    1095 if hasattr(paramiko, 'Ed25519Key'):
#    1096     # NOQA: new in paramiko>=2.2: http://docs.paramiko.org/en/stable/api/keys.html#module-paramiko.ed25519key
#    1097     paramiko_key_types['ed25519'] = paramiko.Ed25519Key
#
# AttributeError: module 'paramiko' has no attribute 'DSSKey'

# %%
pll.par["devices/dlls/picam"] = "path/to/dlls"
from pylablib.devices import PrincetonInstruments
cam = PrincetonInstruments.PicamCamera()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[45], line 3
#       1 pll.par["devices/dlls/picam"] = "path/to/dlls"
#       2 from pylablib.devices import PrincetonInstruments
# ----> 3 cam = PrincetonInstruments.PicamCamera()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam.py:306, in PicamCamera.__init__(self, serial_number)
#     304 self._buffer_readouts=None
#     305 self._waited_readouts=0
# --> 306 self.open()
#     307 self._add_info_variable("device_info",self.get_device_info)
#     308 self._add_info_variable("pixel_size",self.get_pixel_size)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam.py:320, in PicamCamera.open(self)
#     318 if self.handle is not None:
#     319     return
# --> 320 with libctl.temp_open():
#     321     cams=list_cameras()
#     322     serials=[c.serial_number for c in cams]
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\utils\load_lib.py:293, in LibraryController.temp_open(self)
#     291 opid=None
#     292 try:
# --> 293     init_result,open_result,opid=self.open()
#     294     yield init_result,open_result
#     295 finally:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\utils\load_lib.py:258, in LibraryController.open(self)
#     256 init_result=None
#     257 if self.open_devices==0:
# --> 258     init_result=self._do_init() # pylint: disable=assignment-from-no-return
#     259 open_result=self._do_open() # pylint: disable=assignment-from-no-return
#     260 self.open_devices+=1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam.py:22, in LibraryController._do_init(self)
#      21 def _do_init(self):
# ---> 22     lib.Picam_InitializeLibrary()
#
# File <string>:1, in <lambda>()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\core\utils\ctypes_wrap.py:276, in CFunctionWrapper.wrap_annotated.<locals>.wrapped_func(*vargs, **kwargs)
#     274         return a
#     275 call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 276 retval=func(*call_args)
#     277 res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#     278 if (not self.tuple_single_retval) and len(res)==0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:44, in errcheck.<locals>.errchecker(result, func, arguments)
#      42 def errchecker(result, func, arguments):  # pylint: disable=unused-argument
#      43     if result not in passing:
# ---> 44         raise PicamLibError(func.__name__,result,lib=lib)
#      45     return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:27, in PicamLibError.__init__(self, func, code, lib)
#      25 try:
#      26     if lib is not None:
# ---> 27         self.desc=py3.as_str(lib.Picam_GetEnumerationString(PicamEnumeratedType.PicamEnumeratedType_Error,code))
#      28 except PicamError:
#      29     pass
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:271, in PicamLib.Picam_GetEnumerationString(self, stype, value)
#     270 def Picam_GetEnumerationString(self, stype, value):
# --> 271     ptr=self.Picam_GetEnumerationString_lib(stype,value)
#     272     res=ctypes.string_at(ptr)
#     273     self.Picam_DestroyString(ptr)
#
# File <string>:1, in <lambda>(type, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\core\utils\ctypes_wrap.py:276, in CFunctionWrapper.wrap_annotated.<locals>.wrapped_func(*vargs, **kwargs)
#     274         return a
#     275 call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 276 retval=func(*call_args)
#     277 res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#     278 if (not self.tuple_single_retval) and len(res)==0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:44, in errcheck.<locals>.errchecker(result, func, arguments)
#      42 def errchecker(result, func, arguments):  # pylint: disable=unused-argument
#      43     if result not in passing:
# ---> 44         raise PicamLibError(func.__name__,result,lib=lib)
#      45     return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:27, in PicamLibError.__init__(self, func, code, lib)
#      25 try:
#      26     if lib is not None:
# ---> 27         self.desc=py3.as_str(lib.Picam_GetEnumerationString(PicamEnumeratedType.PicamEnumeratedType_Error,code))
#      28 except PicamError:
#      29     pass
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:271, in PicamLib.Picam_GetEnumerationString(self, stype, value)
#     270 def Picam_GetEnumerationString(self, stype, value):
# --> 271     ptr=self.Picam_GetEnumerationString_lib(stype,value)
#     272     res=ctypes.string_at(ptr)
#     273     self.Picam_DestroyString(ptr)
#
# File <string>:1, in <lambda>(type, value)
#
#     [... skipping similar frames: PicamLibError.__init__ at line 27 (421 times), errcheck.<locals>.errchecker at line 44 (421 times), CFunctionWrapper.wrap_annotated.<locals>.wrapped_func at line 276 (421 times), <lambda> at line 1 (420 times), PicamLib.Picam_GetEnumerationString at line 271 (420 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:271, in PicamLib.Picam_GetEnumerationString(self, stype, value)
#     270 def Picam_GetEnumerationString(self, stype, value):
# --> 271     ptr=self.Picam_GetEnumerationString_lib(stype,value)
#     272     res=ctypes.string_at(ptr)
#     273     self.Picam_DestroyString(ptr)
#
# File <string>:1, in <lambda>(type, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\core\utils\ctypes_wrap.py:276, in CFunctionWrapper.wrap_annotated.<locals>.wrapped_func(*vargs, **kwargs)
#     274         return a
#     275 call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 276 retval=func(*call_args)
#     277 res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#     278 if (not self.tuple_single_retval) and len(res)==0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:44, in errcheck.<locals>.errchecker(result, func, arguments)
#      42 def errchecker(result, func, arguments):  # pylint: disable=unused-argument
#      43     if result not in passing:
# ---> 44         raise PicamLibError(func.__name__,result,lib=lib)
#      45     return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pylablib\devices\PrincetonInstruments\picam_lib.py:27, in PicamLibError.__init__(self, func, code, lib)
#      25 try:
#      26     if lib is not None:
# ---> 27         self.desc=py3.as_str(lib.Picam_GetEnumerationString(PicamEnumeratedType.PicamEnumeratedType_Error,code))
#      28 except PicamError:
#      29     pass
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
